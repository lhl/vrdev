# %%
import numpy as np
from   vispy import gloo, app
from   vispy.gloo import Program


# Load the vispy bindings for the iPython Notebook which enables WebGL
# %load_ext vispy.ipython
# Out:
# The vispy.ipython extension is already loaded. To reload it, use:
#   %reload_ext vispy.ipython

# %%
vertex = """
attribute vec2 position;
attribute vec2 texcoord;
varying vec2 v_texcoord;

void main()
{
  gl_Position = vec4(position, 0.0, 1.0);
  v_texcoord = texcoord;
}
"""

# %%
fragment = """
uniform sampler2D texture;
varying vec2 v_texcoord;
void main()
{
  gl_FragColor = texture2D(texture, v_texcoord);
}
"""

# %%
def checkerboard(grid_num=8, grid_size=32):
    row_even = grid_num // 2 * [0, 1]
    row_odd = grid_num // 2 * [1, 0]
    Z = np.row_stack(grid_num // 2 * (row_even, row_odd)).astype(np.uint8)
     return 255 * Z.repeat(grid_size, axis=0).repeat(grid_size, axis=1)
# Out:
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ...
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.

# %%
class Canvas(app.Canvas):
    def __init__(self):
        app.Canvas.__init__(self, size=(512, 512), title='Textured quad',
                            keys='interactive')

        # Build program & data
        self.program = Program(vertex, fragment, count=4)
        self.program['position'] = [(-1, -1), (-1, +1),
                                    (+1, -1), (+1, +1)]
        self.program['texcoord'] = [(0, 0), (1, 0), (0, 1), (1, 1)]
        self.program['texture'] = checkerboard()

        gloo.set_viewport(0, 0, *self.physical_size)

        self.show()

    def on_draw(self, event):
        gloo.set_clear_color('white')
        gloo.clear(color=True)
        self.program.draw('triangle_strip')

    def on_resize(self, event):
        gloo.set_viewport(0, 0, *event.physical_size)
# Out:
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 256
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 256
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 256
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 256
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# ...
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.

# %%
c = Canvas(size=(300, 300))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-b4e1769a6de0> in <module>()
# ----> 1 c = Canvas(size=(300, 300))
#
# <ipython-input-14-754ca2eaa97a> in __init__(self, size)
#      31         self.timer = app.Timer('auto', connect=self.on_timer, start=True)
#      32
# ---> 33         self.show()
#      34
#      35     # ---------------------------------
#
# /usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/canvas.py in show(self, visible, run)
#     427             Run the backend event loop.
#     428         """
# --> 429         self._backend._vispy_set_visible(visible)
#     430         if run:
#     431             self.app.run()
#
# /usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py in _vispy_set_visible(self, visible)
#     197             return
#     198         if self._widget is None:
# --> 199             self._widget = VispyWidget()
#     200             self._widget.set_canvas(self._vispy_canvas)
#     201         display(self._widget)
#
# /usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/ipython/_widget.py in __init__(self, **kwargs)
#      45     def __init__(self, **kwargs):
#      46         super(VispyWidget, self).__init__(**kwargs)
# ---> 47         self.on_msg(self.events_received)
#      48         self.canvas = None
#      49         self.canvas_backend = None
#
# AttributeError: 'VispyWidget' object has no attribute 'on_msg'
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_view' is given but not known.
# WARNING:vispy:Variable 'u_view' is given but not known.
# WARNING: Variable 'a_position' is given but not known.
# WARNING:vispy:Variable 'a_position' is given but not known.
# WARNING: Variable 'a_id' is given but not known.
# WARNING:vispy:Variable 'a_id' is given but not known.
# WARNING: Variable 'u_projection' is given but not known.
# WARNING:vispy:Variable 'u_projection' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Traceback (most recent call last):
#   File "/usr/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/usr/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 403, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 810, in start
#     self._run_callback(callback)
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 592, in _run_callback
#     ret = callback()
#   File "/usr/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 209, in _draw_event
#     self._vispy_canvas.events.draw()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 323, in _handle_exception
#     logger.log_exception()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 265, in log_exception
#     stack = "".join(traceback.format_stack()[:-tb_skip])
#   << caught exception here: >>
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "<ipython-input-14-754ca2eaa97a>", line 70, in on_draw
#     self.program.draw('line_strip')
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/gloo/program.py", line 439, in draw
#     raise RuntimeError('Must have at least one attribute')
# RuntimeError: Must have at least one attribute
# WARNING:vispy:Traceback (most recent call last):
#   File "/usr/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/usr/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 403, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 810, in start
#     self._run_callback(callback)
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 592, in _run_callback
#     ret = callback()
#   File "/usr/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 209, in _draw_event
#     self._vispy_canvas.events.draw()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 323, in _handle_exception
#     logger.log_exception()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 265, in log_exception
#     stack = "".join(traceback.format_stack()[:-tb_skip])
#   << caught exception here: >>
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "<ipython-input-14-754ca2eaa97a>", line 70, in on_draw
#     self.program.draw('line_strip')
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/gloo/program.py", line 439, in draw
#     raise RuntimeError('Must have at least one attribute')
# RuntimeError: Must have at least one attribute
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> for DrawEvent
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> for DrawEvent
# WARNING: Traceback (most recent call last):
#   File "/usr/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/usr/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 403, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 810, in start
#     self._run_callback(callback)
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 592, in _run_callback
#     ret = callback()
#   File "/usr/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 209, in _draw_event
#     self._vispy_canvas.events.draw()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 323, in _handle_exception
#     logger.log_exception()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 265, in log_exception
#     stack = "".join(traceback.format_stack()[:-tb_skip])
#   << caught exception here: >>
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/gloo/context.py", line 170, in flush_commands
#     self.shared.parser.parse([('CURRENT', 0)])
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 110, in parse
#     self._widget.send_glir_commands(commands)
# AttributeError: 'NoneType' object has no attribute 'send_glir_commands'
# WARNING:vispy:Traceback (most recent call last):
#   File "/usr/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/usr/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 403, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 810, in start
#     self._run_callback(callback)
#   File "/usr/lib/python3.5/site-packages/tornado/ioloop.py", line 592, in _run_callback
#     ret = callback()
#   File "/usr/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 209, in _draw_event
#     self._vispy_canvas.events.draw()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 323, in _handle_exception
#     logger.log_exception()
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/logs.py", line 265, in log_exception
#     stack = "".join(traceback.format_stack()[:-tb_skip])
#   << caught exception here: >>
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/gloo/context.py", line 170, in flush_commands
#     self.shared.parser.parse([('CURRENT', 0)])
#   File "/usr/lib/python3.5/site-packages/vispy-0.5.0.dev0-py3.5.egg/vispy/app/backends/_ipynb_webgl.py", line 110, in parse
#     self._widget.send_glir_commands(commands)
# AttributeError: 'NoneType' object has no attribute 'send_glir_commands'
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> for DrawEvent
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> for DrawEvent
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 2
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 2
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 2
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 2
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 4
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 4
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 4
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 4
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 8
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 8
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 8
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 8
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 16
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 16
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 16
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 16
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 32
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 32
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 32
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 32
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 64
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60caf97cc0>> repeat 64
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 64
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60caf97780>> repeat 64
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# ERROR: Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60ca7e9a90>> repeat 512
# ERROR:vispy:Invoking <bound method Canvas.on_draw of <Canvas (ipynb_webgl) at 0x7f60ca7e9a90>> repeat 512
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60ca85ceb8>> repeat 512
# ERROR:vispy:Invoking <bound method GLContext.flush_commands of <GLContext at 0x7f60ca85ceb8>> repeat 512
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
# WARNING: Variable 'u_model' is given but not known.
# WARNING:vispy:Variable 'u_model' is given but not known.
